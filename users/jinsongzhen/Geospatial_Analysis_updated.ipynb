# %% [markdown]
# Geospatial Analysis
# - References: https://github.com/dsgt-birdclef/birdclef-eda-f22/blob/main/users/acmiyaguchi/notebooks/2022-10-23-birdcall-distribution.ipynb

# %%
# !pip install cartopy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cartopy in /usr/lib/python3/dist-packages (0.14.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from cartopy.io import shapereader
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from shapely.geometry import Point, Polygon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-41-d50da374c5bb> in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 from cartopy.io import shapereader
#       6 import cartopy.crs as ccrs
#       7 import cartopy.feature as cfeature
#
# /usr/lib/python3/dist-packages/cartopy/__init__.py in <module>
#     108 # Commonly used sub-modules. Imported here to provide end-user
#     109 # convenience.
# --> 110 import cartopy.crs
#     111 import cartopy.feature
#
# /usr/lib/python3/dist-packages/cartopy/crs.py in <module>
#      34 import six
#      35
# ---> 36 from cartopy._crs import CRS, Geocentric, Geodetic, Globe, PROJ4_VERSION
#      37 import cartopy.trace
#      38
#
# ModuleNotFoundError: No module named 'cartopy._crs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import drive

drive.mount("/content/gdrive/", force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
df = pd.read_csv("/content/gdrive/MyDrive/BirdCLEF/train_metadata.csv")
df.head(50)
# Out:
#    primary_label                                   secondary_labels  \
# 0        afrsil1                                                 []
# 1        afrsil1                     ['houspa', 'redava', 'zebdov']
# 2        afrsil1                                                 []
# 3        afrsil1                                                 []
# 4        afrsil1                                                 []
# 5        afrsil1                                                 []
# 6        afrsil1                                                 []
# 7        afrsil1                                                 []
# 8        afrsil1                                                 []
# 9        afrsil1                                                 []
# 10       afrsil1                                                 []
# 11       afrsil1                                                 []
# 12       afrsil1                                                 []
# 13       afrsil1                                                 []
# 14       afrsil1                                                 []
# 15       afrsil1                                                 []
# 16        akekee                                                 []
# 17        akekee                                                 []
# 18        akekee                              ['apapan', 'warwhe1']
# 19        akekee                                         ['apapan']
# 20        akekee                                           ['iiwi']
# 21        akekee                                                 []
# 22        akepa1   ['akiapo', 'apapan', 'hawama', 'hawcre', 'iiwi']
# 23        akepa1                      ['apapan', 'iiwi', 'warwhe1']
# 24        akepa1                                 ['apapan', 'iiwi']
# 25        akepa1                      ['apapan', 'iiwi', 'warwhe1']
# 26        akepa1  ['akiapo', 'apapan', 'hawama', 'omao', 'warwhe1']
# 27        akepa1                      ['apapan', 'iiwi', 'warwhe1']
# 28        akepa1                                 ['apapan', 'iiwi']
# 29        akepa1                                 ['apapan', 'iiwi']
# 30        akepa1                                           ['iiwi']
# 31        akepa1                                           ['iiwi']
# 32        akiapo                       ['apapan', 'hawama', 'iiwi']
# 33        akiapo                      ['apapan', 'iiwi', 'warwhe1']
# 34        akiapo                                         ['apapan']
# 35        akiapo  ['apapan', 'elepai', 'hawama', 'iiwi', 'omao',...
# 36        akiapo    ['apapan', 'hawama', 'iiwi', 'omao', 'warwhe1']
# 37        akiapo                       ['apapan', 'hawama', 'iiwi']
# 38        akiapo  ['akepa1', 'apapan', 'hawcre', 'omao', 'warwhe1']
# 39        akiapo                                                 []
# 40        akiapo                                 ['hawama', 'iiwi']
# 41        akiapo                                           ['iiwi']
# 42        akiapo                                                 []
# 43        akiapo                                         ['hawama']
# 44        akiapo                                         ['apapan']
# 45        akiapo                                                 []
# 46        akikik                               ['akikik', 'apapan']
# 47        akikik                                                 []
# 48        amewig                                                 []
# 49        amewig                                                 []
#
#                                       type  latitude  longitude  \
# 0                  ['call', 'flight call']   12.3910    -1.4930
# 1                                 ['call']   19.8801  -155.7254
# 2                         ['call', 'song']   16.2901   -16.0321
# 3                   ['alarm call', 'call']   17.0922    54.2958
# 4                          ['flight call']   21.4581  -157.7252
# 5                          ['flight call']   21.4581  -157.7252
# 6                                 ['call']   21.3561  -158.0205
# 7               ['flight call', 'traffic']   10.1538    -0.7996
# 8                                 ['call']   14.5088   -17.0696
# 9                                 ['call']   14.7279   -17.4329
# 10                                ['call']   -1.3306    36.9251
# 11                                ['call']   17.1024    54.4500
# 12                                ['call']   17.1003    54.2844
# 13                                ['call']   17.0922    54.2958
# 14              ['adult', 'sex uncertain']   11.8047    13.1966
# 15                                ['call']   17.0578    42.9626
# 16                                ['call']   22.1467  -159.6134
# 17                                ['call']   22.1467  -159.6134
# 18                        ['call', 'male']   22.1467  -159.6134
# 19                ['call', 'male', 'song']   22.0815  -159.5550
# 20                                ['call']   22.1467  -159.6134
# 21                                ['call']   22.1467  -159.6134
# 22                                ['call']   19.6292  -155.3597
# 23                                ['call']   19.6223  -155.3598
# 24                                ['call']   19.6294  -155.3615
# 25                                ['call']   19.8224  -155.2964
# 26                ['begging call', 'call']   19.5727  -155.3189
# 27                        ['call', 'song']   19.7901  -155.3273
# 28                                ['call']   19.7901  -155.3273
# 29                                ['call']   19.7901  -155.3273
# 30                                ['song']   19.7901  -155.3273
# 31                                ['call']   19.7901  -155.3273
# 32                                ['song']   19.6294  -155.3615
# 33                                ['call']   19.6294  -155.3615
# 34                                ['song']   19.6642  -155.3896
# 35                                ['call']   19.6642  -155.3896
# 36                                ['song']   19.6334  -155.3753
# 37                                ['song']   19.7937  -155.3243
# 38  ['begging call', 'mechanical tapping']   19.5866  -155.3402
# 39                    ['begging call (?)']   19.7901  -155.3273
# 40                                ['call']   19.6759  -155.3845
# 41                        ['call', 'song']   19.6759  -155.3845
# 42                                ['song']   19.6294  -155.3615
# 43                          ['alarm call']   19.6759  -155.3845
# 44                                ['call']   19.5360  -155.3345
# 45             ['adult', 'call', 'female']   19.5361  -155.3247
# 46                                ['call']   22.0815  -159.5550
# 47                                ['call']   22.0815  -159.5550
# 48                                ['call']   56.7264  -111.3803
# 49                                ['call']   56.7264  -111.3803
#
#            scientific_name         common_name                author  \
# 0          Euodice cantans  African Silverbill             Bram Piot
# 1          Euodice cantans  African Silverbill              Dan Lane
# 2          Euodice cantans  African Silverbill             Bram Piot
# 3          Euodice cantans  African Silverbill        Oscar Campbell
# 4          Euodice cantans  African Silverbill         Ross Gallardy
# 5          Euodice cantans  African Silverbill         Ross Gallardy
# 40   https://www.xeno-canto.org/27374    akiapo/XC27374.ogg
# 41   https://www.xeno-canto.org/27376    akiapo/XC27376.ogg
# 42  https://www.xeno-canto.org/306424   akiapo/XC306424.ogg
# 43  https://www.xeno-canto.org/385387   akiapo/XC385387.ogg
# 44  https://www.xeno-canto.org/648118   akiapo/XC648118.ogg
# 45  https://www.xeno-canto.org/648120   akiapo/XC648120.ogg
# 46  https://www.xeno-canto.org/216038   akikik/XC216038.ogg
# 47  https://www.xeno-canto.org/317034   akikik/XC317034.ogg
# 48  https://www.xeno-canto.org/150015   amewig/XC150015.ogg
# 49  https://www.xeno-canto.org/150063   amewig/XC150063.ogg

# %% [markdown]
# From the [Kaggle data page](https://www.kaggle.com/competitions/birdclef-2022/data), here are some details about the columns of `df`:
#
# - primary_label - a code for the bird species. You can review detailed information about the bird codes at https://ebird.org/species/amecro for the American Crow, for example.
# - secondary_labels: Background species as annotated by the recordist. An empty list does not mean that no background birds are audible.
# - author - the eBird user who provided the recording.
# - filename: the associated audio file.
# - rating: Float value between 0.0 and 5.0 as an indicator of the quality rating on Xeno-canto and the number of background species, where 5.0 is the highest and 1.0 is the lowest. 0.0 means that this recording has no user rating yet.

# %% [markdown]
# # Data Preparation
#
# - The distribution maps can act as important priors for classification tasks.

# %%
visual_df = df.copy()
# groupby() with as_index = False returns a data frame
top_10_df = (
    visual_df.groupby("primary_label", as_index=False)
    .size()
    .nlargest(10, "size", keep="all")
)

# top 10 bird species by population
top_10_list = list(top_10_df["primary_label"])
top_10_df
# Out:
#     primary_label  size
# 21         brnowl   500
# 41         comsan   500
# 68         houspa   500
# 87        mallar3   500
# 94         norcar   500
# 131        skylar   500
# 45         dunlin   476
# 53         gnwtea   463
# 10         bcnher   462
# 96         normoc   387

# %%
def plot_lonlat1(df: pd.DataFrame, **kwargs):
    """Plot longitude vs latitude."""
    x = df["longitude"]
    y = df["latitude"]
    plt.scatter(x, y, s=3, **kwargs)
    plt.title("Longitude vs Latitude")
    plt.xlabel("longitude")
    plt.ylabel("Latitude")
    plt.show()


def plot_lonlat(df: pd.DataFrame, bird: str, **kwargs):
    """Plot longitude vs latitude."""
    x = df["longitude"]
    y = df["latitude"]
    plt.scatter(x, y, s=3, **kwargs)
    plt.title("{} longitude vs latitude".format(bird))
    plt.xlabel("longitude")
    plt.ylabel("Latitude")
    plt.show()


plot_lonlat1(df)

# %% [markdown]
# Goal: Plot the top 10 species
# - The first 5 bird species each have 500 habitats being the most populated
# - Most of them are located at the Northern Hemisphere above 20th parallel north
# -  Among the top 10 speicies, 8 of them seem to gather at one place or around, with only some individual groups that are scattered everywhere

# %%
for bird in top_10_list:
    df1 = visual_df[visual_df["primary_label"] == bird]
    plot_lonlat(df1, bird)
    print("\n")

# %%
df.loc[
    (df["secondary_labels"].str.len() != 2), :
].head()  # not a string '' in the column of the secondary label
# find the potential neighbor bird species, exclude rows without any label
# Out:
#    primary_label                                  secondary_labels  \
# 1        afrsil1                    ['houspa', 'redava', 'zebdov']
# 18        akekee                             ['apapan', 'warwhe1']
# 19        akekee                                        ['apapan']
# 20        akekee                                          ['iiwi']
# 22        akepa1  ['akiapo', 'apapan', 'hawama', 'hawcre', 'iiwi']
#
#                         type  latitude  longitude         scientific_name  \
# 1                   ['call']   19.8801  -155.7254         Euodice cantans
# 18          ['call', 'male']   22.1467  -159.6134  Loxops caeruleirostris
# 19  ['call', 'male', 'song']   22.0815  -159.5550  Loxops caeruleirostris
# 20                  ['call']   22.1467  -159.6134  Loxops caeruleirostris
# 22                  ['call']   19.6292  -155.3597        Loxops coccineus
#
#            common_name         author  \
# 1   African Silverbill       Dan Lane
# 18              Akekee  Ross Gallardy
# 19              Akekee  Patrick Blake
# 20              Akekee    Daniel Lane
# 22        Hawaii Akepa   Brooks Rownd
#
#                                               license  rating   time  \
# 1   Creative Commons Attribution-NonCommercial-Sha...     3.5  08:30
# 18  Creative Commons Attribution-NonCommercial-Sha...     4.5  09:00
# 19  Creative Commons Attribution-NonCommercial-Sha...     3.5  14:00
# 20  Creative Commons Attribution-NonCommercial-Sha...     3.5  12:30
# 22  Creative Commons Attribution-NonCommercial-Sha...     2.5  14:14
#
#                                   url              filename
# 1   https://www.xeno-canto.org/175522  afrsil1/XC175522.ogg
# 18  https://www.xeno-canto.org/210201   akekee/XC210201.ogg
# 19  https://www.xeno-canto.org/219961   akekee/XC219961.ogg
# 20   https://www.xeno-canto.org/27306    akekee/XC27306.ogg
# 22  https://www.xeno-canto.org/122473   akepa1/XC122473.ogg

# %%
# Use cartopy and shapely tools to plot birdcall data in United States
subset_df = df[["primary_label", "latitude", "longitude"]].dropna()

reader = shapereader.Reader(
    shapereader.natural_earth(
        resolution="50m", category="cultural", name="admin_0_countries"
    )
)
US = [
    s for s in reader.records() if s.attributes["ADMIN"] == "United States of America"
][0]

fig = plt.figure(figsize=(15, 11))
projection = ccrs.PlateCarree()

ax = plt.axes(projection=projection)
ax.stock_img()
# xlim and ylim for United States, manually found
ax.set_xlim(-180, -60)
ax.set_ylim(15, 90)
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)

ax.add_feature(
    cfeature.ShapelyFeature([US.geometry], projection),
    edgecolor="k",
    facecolor=(1, 1, 1, 0),
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-86e8c97fce64> in <module>
#       2 subset_df = df[["primary_label", "latitude", "longitude"]].dropna()
#       3
# ----> 4 reader = shapereader.Reader(
#       5     shapereader.natural_earth(
#       6         resolution="50m", category="cultural", name="admin_0_countries"
#
# NameError: name 'shapereader' is not defined

# %%
points_in_US = subset_df.apply(
    lambda x: US.geometry.contains(Point(x.longitude, x.latitude)), axis=1
)
US_df = subset_df[points_in_US]
print("Top 10 bird species in US: ")
print(US_df.primary_label.value_counts()[:10].to_dict())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-2aec86e8743f> in <module>
# ----> 1 points_in_US = subset_df.apply(
#       2     lambda x: US.geometry.contains(Point(x.longitude, x.latitude)), axis=1
#       3 )
#       4 US_df = subset_df[points_in_US]
#       5 print("Top 10 bird species in US: ")
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-39-2aec86e8743f> in <lambda>(x)
#       1 points_in_US = subset_df.apply(
# ----> 2     lambda x: US.geometry.contains(Point(x.longitude, x.latitude)), axis=1
#       3 )
#       4 US_df = subset_df[points_in_US]
#       5 print("Top 10 bird species in US: ")
#
# NameError: name 'US' is not defined

# %% [markdown]
# Plot with bird speicies data points on the map within the US boundary

# %%
fig = plt.figure(figsize=(12, 7))
projection = ccrs.PlateCarree()

ax = plt.axes(projection=projection)
ax.stock_img()
ax.set_xlim(-180, -60)
ax.set_ylim(15, 80)
ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)

ax.add_feature(
    cfeature.ShapelyFeature([US.geometry], projection),
    edgecolor="k",
    facecolor=(1, 1, 1, 0),
)

# add points from the US subset
# show the map for top 10 bird specieis
for bird in top_10_list:
    US_df1 = US_df[US_df["primary_label"] == bird]
    for i, row in US_df1.iterrows():
        ax.plot(
            row.longitude,
            row.latitude,
            "o",
            color="r",
            transform=ccrs.PlateCarree(),
            alpha=0.5,
        )

    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-2f29c63bb5ff> in <module>
#       1 fig = plt.figure(figsize=(12, 7))
# ----> 2 projection = ccrs.PlateCarree()
#       3
#       4 ax = plt.axes(projection=projection)
#       5 ax.stock_img()
#
# NameError: name 'ccrs' is not defined

# %% [markdown]
# Discretize Geographical Data

# %%
def generate_grid(df, shape, map_dims, grid_dims):
    xmin, xmax, ymin, ymax = map_dims
    length, width = grid_dims

    # generate a grid of polygons that intersect with the provided shape
    polygons = {}
    cols = list(np.arange(xmin, xmax + width, width))
    rows = list(np.arange(ymin, ymax + length, length))
    for x in cols[:-1]:
        for y in rows[:-1]:
            polygon = Polygon(
                [(x, y), (x + width, y), (x + width, y + length), (x, y + length)]
            )
            if shape.geometry.intersects(polygon):
                polygons[f"{x}_{y}"] = polygon

    # now generate a new dataframe where points are contained within the shape
    points = df.apply(
        lambda x: shape.geometry.contains(Point(x.longitude, x.latitude)), axis=1
    )
    res_df = subset_df[points].copy()

    # add the appropriate grid for each point
    res_df["grid"] = res_df.apply(
        lambda x: [
            k for k, p in polygons.items() if p.contains(Point(x.longitude, x.latitude))
        ][0],
        axis=1,
    )
    return res_df, polygons


US_df, polygons = generate_grid(subset_df, US, [-180, -60, 15, 80], [0.5, 0.5])
print(f"{len(polygons)} grid items")
US_df.head()
# Out:
# 4973 grid items
#    primary_label  latitude  longitude         grid
# 1        afrsil1   19.8801  -155.7254  -156.0_19.5
# 6        afrsil1   21.3561  -158.0205  -158.5_21.0
# 16        akekee   22.1467  -159.6134  -160.0_22.0
# 17        akekee   22.1467  -159.6134  -160.0_22.0
# 18        akekee   22.1467  -159.6134  -160.0_22.0

# %%
fig = plt.figure(figsize=(30, 26))
projection = ccrs.PlateCarree()
ax = plt.axes(projection=projection)
ax.stock_img()
ax.set_xlim(-180, -60)
ax.set_ylim(15, 80)

# log scale the counts
size = np.log(US_df.groupby("grid").size())
expected = size.mean()
vmin = size.min()
vmax = size.max()
color_getter = lambda x: plt.get_cmap("viridis")(np.interp(x, [vmin, vmax], [0, 1]))

for key, polygon in polygons.items():
    ax.add_feature(
        cfeature.ShapelyFeature([polygon], projection),
        edgecolor="gray",
        facecolor=color_getter(US_df[US_df.grid == key].shape[0]),
    )

ax.add_feature(
    cfeature.ShapelyFeature([US.geometry], projection),
    edgecolor="k",
    facecolor=(1, 1, 1, 0),
)

cbar = fig.colorbar(plt.matplotlib.cm.ScalarMappable(norm=None, cmap="viridis"), ax=ax)
cbar.set_ticks(np.linspace(0, 1, 6))
cbar.set_ticklabels(
    [f"{round(np.interp(x, [0, 1], [vmin, vmax]), 2)}" for x in cbar.get_ticks()]
)

plt.show()

# %% [markdown]
# Kernel Density Estimate of Species Distributions
#
# - Bandwidth determines how smooth the resulting curve is.
# - Haversine distance metrics measures the angular distance between points on a sphere and can be used with kernel density estimator.

# %% [markdown]
# Visualize lattitude vs density and longittude vs density respectively
# - adjust the bw_adjust parameter to make the curve more smoothing
# - KDE Plot, also called Kernel Density Estimate, helps visualizing the probability density of a continuous variable if performing kernel density estimation for lattitude / longitude in this case. It shows the probability density at different values in a continuous value.

# %%
import seaborn as sns

sns.set_style("whitegrid")
sns.kdeplot(x=df.longitude, bw_adjust=0.9)

# %%
sns.kdeplot(x=df.latitude, bw_adjust=0.7)

# %%
# kernel density estimation with 2-d array shown as below
import numpy as np
from sklearn.neighbors import KernelDensity

# convert to np array
np_kd = df[["longitude", "latitude"]].to_numpy()

# The bigger the bandwidth, the smoother the distribution is
kde = KernelDensity(
    metric="haversine", kernel="gaussian", bandwidth=0.05, algorithm="ball_tree"
)
kde = kde.fit(np_kd)
kde.score_samples(np_kd)
# Out:
# array([-5.45230233, -4.4582984 , -4.75915515, ..., -3.69732009,
#        -3.682717  , -3.682717  ])

# %%
# contour plot using seaborn
import seaborn as sns

# set seaborn style
sns.set_style("whitegrid")

# Basic 2D density plot
sns.kdeplot(x=df.longitude, y=df.latitude)
plt.show()
# with shade
sns.kdeplot(x=df.longitude, y=df.latitude, cmap="Reds", shade=True, bw_adjust=0.8)
plt.show()
# With thresh parameter
sns.kdeplot(x=df.longitude, y=df.latitude, cmap="Blues", shade=True, thresh=0)
plt.show()

# %% [markdown]
# Visualizing histogram with Matplotlib and Pandas

# %%
sns.histplot(x=df.longitude, kde=True)

# %%
sns.histplot(x=df.latitude, kde=True)

# %% [markdown]
# - Create a density map to show which bird species are located. The point data can be smoothed into a heat map
# - sns has a plot function analogous to a Heat Map

# %%
sns.displot(df, x=df.longitude, y=df.latitude, cbar=True)

# %% [markdown]
# The contour approach of the bivariate KDE plot lends itself better to evaluating overlap.

# %%
sns.displot(df, x=df.longitude, y=df.latitude, kind="kde")

# %%
top_10_list
# Out:
# ['brnowl',
#  'skylar',
#  'norcar',
#  'mallar3',
#  'houspa',
#  'comsan',
#  'dunlin',
#  'gnwtea',
#  'bcnher',
#  'normoc']
